# %% [markdown]
# # 第1章: 準備運動

# %% [markdown]
# ## 00. パタトクカシーー
# 2つの文字列「パトカー」と「タクシー」の文字を先頭から交互に連結し、文字列「パタトクカシーー」を得よ。

# %%
str1 = "パトカー"
str2 = "タクシー"
comb = ''.join([''.join(pair) for pair in zip(list(str1), list(str2))])
print(comb)
# Out:
# パタトクカシーー

# %% [markdown]
# ## 01. タクシー
# 文字列「パタトクカシーー」の2, 4, 6, 8文字目を取り出し、それらを連結した文字列を得よ。

# %%
str1 = "パタトクカシーー"
indices = [1, 3, 5, 7]
ans = ''.join([str1[i] for i in indices])
print(ans)
# Out:
# タクシー

# %% [markdown]
# ## 02. 文字列の逆順
# 文字列"stressed"の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ。

# %%
str1 = "stressed"
str_reversed = str1[::-1]
print(str1[::-1])
# Out:
# desserts

# %% [markdown]
# ## 03. 円周率
# "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."という文を単語に分解し、各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ。

# %%
str1 = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."
remove_punct = str1[:-1].split(',')
target = [len(word) for word in (''.join(remove_punct)).split()]
print(target)
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# ## 04. 元素記号
# "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."という文を単語に分解し、1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字、それ以外の単語は先頭の2文字を取り出し、取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ。

# %%
src = "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
one_char_indices = [1, 5, 6, 7, 8, 9, 15, 16, 19]
src_list = src.split()
extracted_str = [word[0] if idx in one_char_indices else word[0:2] for idx, word in enumerate(src_list)]
mapping = {idx : string for idx, string in enumerate(extracted_str)}
print(mapping)
# Out:
# {0: 'Hi', 1: 'H', 2: 'Li', 3: 'Be', 4: 'Bo', 5: 'C', 6: 'N', 7: 'O', 8: 'F', 9: 'N', 10: 'Na', 11: 'Mi', 12: 'Al', 13: 'Si', 14: 'Pe', 15: 'S', 16: 'C', 17: 'Ar', 18: 'Ki', 19: 'C'}

# %% [markdown]
# ## 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ。この関数を用い、"I am an NLPer"という文から文字tri-gram、単語bi-gramを得よ。

# %%
def n_gram(n, seq):
  n_gram = []
  for idx in range(len(seq)-(n-1)):
    n_gram.append(seq[idx:idx+n])
  return n_gram

src = "I am an NLPer"
print(f"character tri-gram: {n_gram(3, ''.join(src.split()))}")
print(f"word bi-gram: {n_gram(2, src.split())}")
# Out:
# character tri-gram: ['Iam', 'ama', 'man', 'anN', 'nNL', 'NLP', 'LPe', 'Per']
# word bi-gram: [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]

# %% [markdown]
# ## 06. 集合
# "paraparaparadise"と"paragraph"に含まれる文字bi-gramの集合を、それぞれ, $X$ と $Y$ として求め、$X$ と $Y$ の和集合（$X \cup Y$）、積集合（$X \cap Y$）、差集合（$X \setminus Y$）を求めよ。さらに、'se'というbi-gramがXおよびYに含まれるかどうかを調べよ。

# %%
def n_gram(n, seq):
  n_gram = []
  for idx in range(len(seq)-(n-1)):
    n_gram.append(seq[idx:idx+n])
  return n_gram

X = set(n_gram(2, "paraparaparadise"))
Y = set(n_gram(2, "paragraph"))
print(f"intersection: {X & Y}")
print(f"union: {X | Y}")
print(f"difference: {X - Y}")
print(f"is included in X: {"se" in X}")
print(f"is included in Y: {"se" in Y}")
# Out:
# intersection: {'ar', 'ra', 'pa', 'ap'}
# union: {'is', 'ag', 'ap', 'di', 'ar', 'ad', 'pa', 'gr', 'ph', 'se', 'ra'}
# difference: {'is', 'ad', 'se', 'di'}
# is included in X: True
# is included in Y: False

# %% [markdown]
# ## 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ。さらに、x=12, y="気温", z=22.4として、実行結果を確認せよ。

# %%
def template(x: int, y: str, z: float) -> str:
  return f"{x}時の{y}は{z}"

print(template(12, "temp", "22.4"))
# Out:
# 12時のtempは22.4

# %% [markdown]
# ## 08. 暗号文
# 与えられた文字列の各文字を、以下の仕様で変換する関数cipherを実装せよ。
#
# * 英小文字ならば (219 - 文字コード) のASCIIコードに対応する文字に置換
# * その他の文字はそのまま出力
#
# この関数を用い、英語のメッセージを暗号化・復号化せよ。

# %% [markdown]
# ## 09. Typoglycemia
# スペースで区切られた単語列に対して、各単語の先頭と末尾の文字は残し、それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ。ただし、長さが４以下の単語は並び替えないこととする。適当な英語の文（例えば"I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."）を与え、その実行結果を確認せよ。
